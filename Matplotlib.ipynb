# %%
from m8r import view

# %%
# %%file 1_welcome.scons
#
#
# Flow('welcome',None,
#      'spike n1=1000 k1=300 | bandpass fhi=2 phase=1')
#
# # view=1: display on the screen without generating a figure
# Plot('welcome',
#      '''
#      matplotlib plot title="Welcome to Madagascar"
#      grid=y linewidth=3
#      ''',view=1)
#
# Result('welcome',
#        '''
#        matplotlib plot title="Welcome to Madagascar"
#        grid=y linewidth=3
#        ''')
# Out:
# Overwriting 1_welcome.scons

# %%
view("welcome")
